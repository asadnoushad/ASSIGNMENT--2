# %% [markdown]
# <a href="https://colab.research.google.com/github/asadnoushad/ASSIGNMENT--2/blob/main/odd_or_even_checker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Check if a Number is Even or Odd

num=int(input("enter a number\t"))
if num % 2==0:
  print(num," is an even number")
else:
  print(num," is an odd number")
# Out:
# enter a number	77
# 77  is an odd number
